# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

# %%
from fem.solver import CahnHilliardSolver
import numpy as np
import matplotlib.pyplot as plt

# Physics
epsilon = 0.01

# Discretization
L = 1
N = 50
poly_degree = 1


dt = 1e-8
tEnd = dt*1e4
# tEnd = 1e-3
print(int(tEnd/dt))

# Initial conditions
def c0(x): return np.cos(np.pi*x)
# Out:
# 10000

# %%
explicit = CahnHilliardSolver(epsilon, 
                         number_of_elements=N, L = L, 
                         polynomial_order=1)
explicit.solve(c0, tEnd, dt, time_integrator=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 explicit = CahnHilliardSolver(epsilon,
#       2                          number_of_elements=N, L = L,
#       3                          polynomial_order=1)
# ----> 4 explicit.solve(c0, tEnd, dt, time_integrator=1)
#
# File c:\GIT\MMSC-Scientific-Computing\fem\solver.py:198, in CahnHilliardSolver.solve(self, u0, T, dt, time_integrator, non_linear_solver)
#     194 self.__J[0] = self.__compute_J(self.__u[0])
#     196 ################################################
#     197 # TIME STEPPING
# --> 198 _time_stepper()
#
# File c:\GIT\MMSC-Scientific-Computing\fem\solver.py:326, in CahnHilliardSolver._implicit(self)
#     324 """Implicit time stepping"""
#     325 # Compute COnstant blocks of Jacobian
# --> 326 Jac = self.__assemble_Jacobian()
#     327 for it in range(1,self.__nt):
#     328     self.__u[it] = self._NewtonRaphson(self.__u[it-1], Jac)
#
# File c:\GIT\MMSC-Scientific-Computing\fem\solver.py:261, in CahnHilliardSolver.__assemble_Jacobian(self)
#     259 def __assemble_Jacobian(self):
#     260     J = np.zeros((2*self.__N, 2*self.__N), dtype=float)
# --> 261     J = bmat([[self.M/self.__dt, self.K],
#     262               [np.zeros(self.__N), self.M]], format = 'csc')
#     263     return csc_matrix(J)
#
# File c:\Users\Segundo\miniconda3\envs\ox\Lib\site-packages\scipy\sparse\_construct.py:913, in bmat(blocks, format, dtype)
#     911     return _block(blocks, format, dtype)
#     912 else:
# --> 913     return _block(blocks, format, dtype, return_spmatrix=True)
#
# File c:\Users\Segundo\miniconda3\envs\ox\Lib\site-packages\scipy\sparse\_construct.py:1016, in _block(blocks, format, dtype, return_spmatrix)
#    1012 elif brow_lengths[i] != A._shape_as_2d[0]:
#    1013     msg = (f'blocks[{i},:] has incompatible row dimensions. '
#    1014            f'Got blocks[{i},{j}].shape[0] == {A._shape_as_2d[0]}, '
#    1015            f'expected {brow_lengths[i]}.')
# -> 1016     raise ValueError(msg)
#    1018 if bcol_lengths[j] == 0:
#    1019     bcol_lengths[j] = A._shape_as_2d[1]
#
# ValueError: blocks[1,:] has incompatible row dimensions. Got blocks[1,1].shape[0] == 51, expected 1.

# %%
explicit.plot_contour()

# %%
fig1, ax1 = plt.subplots(1,2)
ax1[0].plot(explicit.x, explicit.sol_c[0])
ax1[1].plot(explicit.x, explicit.sol_w[0])
if len(explicit.t) > 1:
    for i in range(1,len(explicit.t), len(explicit.t)//10):
        ax1[0].plot(explicit.x, explicit.sol_c[i])
        ax1[1].plot(explicit.x, explicit.sol_w[i])
ax1[0].set_title('c(x)')
ax1[1].set_title('w(x)')
fig1.tight_layout()

fig2, ax2 = plt.subplots(1,2)
ax2[0].plot(explicit.t/dt/1e3, explicit.mass)
ax2[1].plot(explicit.t/dt/1e3, explicit.J)

ax2[0].set_title('$\\mathcal{M}(C)$')
ax2[1].set_title('$\\mathcal{J}(C)$')
[_.set_xlabel('Time step (x1000)') for _ in ax2]
fig2.tight_layout()

# %% [markdown]
# # IMPLICIT SOLVER

# %% [markdown]
# # Semi-Implicit Solver

# %% [markdown]
# ## Case A

# %% [markdown]
# # Case B
